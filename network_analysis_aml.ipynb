# %% [markdown]
# <h1>
#     Network Analysis for Anti-Money Laundering with NetworkX and gravis
# </h1>

# %% [markdown]
# <h4>
#     Importing necessary libraries
# </h4>

# %%
import pandas as pd
import networkx as nx
import itertools
from distinctipy import distinctipy
import gravis as gv

# %% [markdown]
# <h3>
#     For our analysis we are using a dataset generated from IBM AMLSim. The same is also available in kaggle.
# </h3>
# <h4>
#     There are a total of 8 columns in this dataset.
# </h4>
# <br/>
# <table style='float:left'>
#     <tr>
#         <th>Column Name</th>
#         <th>Data Understanding</th>
#     </tr>
#     <tr>
#         <td>TX_ID</td>
#         <td>Transaction ID</td>
#     </tr>
#     <tr>
#         <td>SENDER_ACCOUNT_ID</td>
#         <td>Account ID of the person sending the fund</td>
#     </tr>
#     <tr>
#         <td>RECEIVER_ACCOUNT_ID</td>
#         <td>Account ID of the person receiving the fund</td>
#     </tr>
#     <tr>
#         <td>TX_TYPE</td>
#         <td>Type of Transaction. All are TRANSFER transactions.</td>
#     </tr>
#     <tr>
#         <td>TX_AMOUNT</td>
#         <td>Amount of the Transaction</td>
#     </tr>
#     <tr>
#         <td>TIMESTAMP</td>
#         <td>A simulated transaction timestamp starting with 0 to 199</td>
#     </tr>
#     <tr>
#         <td>IS_FRAUD</td>
#         <td>Label for the transaction being a potential fraud. An Investigator need to verify these alerts through various method starting with network analysis</td>
#     </tr>
#     <tr>
#         <td>ALERT_ID</td>
#         <td>ID of ALERT that got triggered for the transaction</td>
#     </tr>
# </table>

# %%
pd.set_option("display.max_colwidth",None)
full_txn_df = pd.read_csv("transactions.csv")
full_txn_df
# Out:
#            TX_ID  SENDER_ACCOUNT_ID  RECEIVER_ACCOUNT_ID   TX_TYPE  TX_AMOUNT  \
# 0              1               6456                 9069  TRANSFER     465.05
# 1              2               7516                 9543  TRANSFER     564.64
# 2              3               2445                 9356  TRANSFER     598.94
# 3              4               2576                 4617  TRANSFER     466.07
# 4              5               3524                 1773  TRANSFER     405.63
# ...          ...                ...                  ...       ...        ...
# 1323229  1323230               3733                 8051  TRANSFER     112.98
# 1323230  1323231               2536                 8732  TRANSFER     459.64
# 1323231  1323232               1466                 8586  TRANSFER     468.60
# 1323232  1323233               1451                 3849  TRANSFER     562.36
# 1323233  1323234                545                 2724  TRANSFER     415.57
#
#          TIMESTAMP  IS_FRAUD  ALERT_ID
# 0                0     False        -1
# 1                0     False        -1
# 2                0     False        -1
# 3                0     False        -1
# 4                0     False        -1
# ...            ...       ...       ...
# 1323229        199     False        -1
# 1323230        199     False        -1
# 1323231        199     False        -1
# 1323232        199     False        -1
# 1323233        199     False        -1
#
# [1323234 rows x 8 columns]

# %% [markdown]
# <h4> We are selecting the relevant columns to proceed next</h4>

# %%
full_txn_df = full_txn_df[["SENDER_ACCOUNT_ID","RECEIVER_ACCOUNT_ID","TX_AMOUNT","IS_FRAUD"]]
full_txn_df
# Out:
#          SENDER_ACCOUNT_ID  RECEIVER_ACCOUNT_ID  TX_AMOUNT  IS_FRAUD
# 0                     6456                 9069     465.05     False
# 1                     7516                 9543     564.64     False
# 2                     2445                 9356     598.94     False
# 3                     2576                 4617     466.07     False
# 4                     3524                 1773     405.63     False
# ...                    ...                  ...        ...       ...
# 1323229               3733                 8051     112.98     False
# 1323230               2536                 8732     459.64     False
# 1323231               1466                 8586     468.60     False
# 1323232               1451                 3849     562.36     False
# 1323233                545                 2724     415.57     False
#
# [1323234 rows x 4 columns]

# %% [markdown]
# <h3>
#     The next step is to Determine the sample size for our analysis. One way to do it is by calculating the max group or connected components size by iterating through various sample sizes. It's important to do that beforehand because without a manageable group size, it's very difficult to visualize and analyse the fund flow traces.
# </h3>
# <h4>
#     For our analysis, we are selecting a random sample based on sample size. However, in real life, we have to determine our assessment or look-back period based on the connected component size. Thus by trying different timeframe coverage, such as weekly, monthly, quarterly, yearly or so, we can determine the manageable timeframe coverage and proceed with that for the rest analysis.
# </h4>

# %%
max_group_sizes = list()
for i in range(500,10000,500):
    cur_max_group_size = dict()
    cur_max_group_size["sample_size"] = i
    sample_df = full_txn_df.sample(i,random_state=2)
    sample_df = sample_df.groupby(["SENDER_ACCOUNT_ID","RECEIVER_ACCOUNT_ID"],as_index=False).agg({"TX_AMOUNT":["count","sum"]})
    sample_df.columns = ["SENDER_ACCOUNT_ID","RECEIVER_ACCOUNT_ID","TXN_COUNT","TOTAL_TXN_AMOUNT"]
    sample_net = nx.from_pandas_edgelist(sample_df,source="SENDER_ACCOUNT_ID",target="RECEIVER_ACCOUNT_ID", create_using = nx.DiGraph())
    cur_max_group_size["max_group_size"] = len(max(nx.weakly_connected_components(sample_net),key=len))
    max_group_sizes.append(cur_max_group_size)
max_group_sizes = pd.DataFrame(max_group_sizes)
max_group_sizes
# Out:
#     sample_size  max_group_size
# 0           500               6
# 1          1000               9
# 2          1500              22
# 3          2000              33
# 4          2500              95
# 5          3000             246
# 6          3500             767
# 7          4000            1297
# 8          4500            1886
# 9          5000            2470
# 10         5500            3096
# 11         6000            3537
# 12         6500            3963
# 13         7000            4387
# 14         7500            4707
# 15         8000            5041
# 16         8500            5359
# 17         9000            5608
# 18         9500            5845

# %% [markdown]
# <h4>
#     From the above analysis, we can see with 2000 samples the max_group_size is 33. And it becomes 95 and increases further with more sample sizes.
# </h4>
# <h4>We will proceed with a manageable sample size of 2000 for the rest of the analysis</h4>

# %%
analysis_df = full_txn_df.sample(2000,random_state=2)
analysis_df
# Out:
#          SENDER_ACCOUNT_ID  RECEIVER_ACCOUNT_ID  TX_AMOUNT  IS_FRAUD
# 339046                9060                 5397       5.34     False
# 512340                3503                 3337     594.95     False
# 1015893               3452                  352     519.40     False
# 29301                 3578                 9078     457.42     False
# 624805                7523                 2425     498.02     False
# ...                    ...                  ...        ...       ...
# 329362                8425                 9695     535.91     False
# 107287                6411                  146     434.66     False
# 1196849               2175                 8022      20.60     False
# 512501                3607                 2098     169.00     False
# 999270                5101                 4255      21.36     False
#
# [2000 rows x 4 columns]

# %% [markdown]
# <h4>
#     The rows below in our sample are flagged as fraudulent by the alerting system. Will perform network analysis for the below accounts of interest later in our analysis process.
# </h4>

# %%
analysis_df.loc[analysis_df["IS_FRAUD"]]
# Out:
#          SENDER_ACCOUNT_ID  RECEIVER_ACCOUNT_ID  TX_AMOUNT  IS_FRAUD
# 380151                9070                 9849       3.04      True
# 1108504               7803                 8589      11.27      True
# 617788                8316                 6794       4.74      True
# 1082414               9922                 1149       3.97      True
# 589896                4155                 7628      11.52      True

# %% [markdown]
# <h4>
#     Consolidating all the transactions between each Sender->Receiver pair to have a more clear understanding of the consolidated total fund flow and the same can be visualized for a better analysis
# </h4>

# %%
aml_df = analysis_df.groupby(["SENDER_ACCOUNT_ID","RECEIVER_ACCOUNT_ID"],as_index=False).agg({"TX_AMOUNT":["count","sum"]})
aml_df.columns = ["SENDER_ACCOUNT_ID","RECEIVER_ACCOUNT_ID","TXN_COUNT","TOTAL_TXN_AMOUNT"]
aml_df
# Out:
#       SENDER_ACCOUNT_ID  RECEIVER_ACCOUNT_ID  TXN_COUNT  TOTAL_TXN_AMOUNT
# 0                    28                 9984          1             95.65
# 1                    48                 9256          1             61.93
# 2                    53                 9600          1             44.00
# 3                    60                 9328          1             60.48
# 4                    70                 4385          2             79.28
# ...                 ...                  ...        ...               ...
# 1898               9990                 3759          1            209.22
# 1899               9995                 1217          1            394.35
# 1900               9996                 2428          1            344.98
# 1901               9996                 9993          1            344.98
# 1902               9997                 9863          1            260.85
#
# [1903 rows x 4 columns]

# %% [markdown]
# <h4>
#     Populating two more columns "hover" and "click" for using as an edge attribute in our network. Thus making it easier to view the details of each consolidated transaction while visualizing.
# </h4>

# %%
aml_df = aml_df.assign(hover=aml_df.apply(lambda x: f"From: {int(x['SENDER_ACCOUNT_ID'])}\nTo: {int(x['RECEIVER_ACCOUNT_ID'])}\nTransaction Count: {int(x['TXN_COUNT'])}\nTotal Transaction Amount: {x['TOTAL_TXN_AMOUNT']}",axis=1))
aml_df["click"] = aml_df["hover"]
aml_df
# Out:
#       SENDER_ACCOUNT_ID  RECEIVER_ACCOUNT_ID  TXN_COUNT  TOTAL_TXN_AMOUNT  \
# 0                    28                 9984          1             95.65
# 1                    48                 9256          1             61.93
# 2                    53                 9600          1             44.00
# 3                    60                 9328          1             60.48
# 4                    70                 4385          2             79.28
# ...                 ...                  ...        ...               ...
# 1898               9990                 3759          1            209.22
# 1899               9995                 1217          1            394.35
# 1900               9996                 2428          1            344.98
# 1901               9996                 9993          1            344.98
# 1902               9997                 9863          1            260.85
#
#                                                                              hover  \
# 0        From: 28\nTo: 9984\nTransaction Count: 1\nTotal Transaction Amount: 95.65
# 1        From: 48\nTo: 9256\nTransaction Count: 1\nTotal Transaction Amount: 61.93
# 2         From: 53\nTo: 9600\nTransaction Count: 1\nTotal Transaction Amount: 44.0
# 3        From: 60\nTo: 9328\nTransaction Count: 1\nTotal Transaction Amount: 60.48
# 4        From: 70\nTo: 4385\nTransaction Count: 2\nTotal Transaction Amount: 79.28
# ...                                                                            ...
# 1898  From: 9990\nTo: 3759\nTransaction Count: 1\nTotal Transaction Amount: 209.22
# 1899  From: 9995\nTo: 1217\nTransaction Count: 1\nTotal Transaction Amount: 394.35
# 1900  From: 9996\nTo: 2428\nTransaction Count: 1\nTotal Transaction Amount: 344.98
# 1901  From: 9996\nTo: 9993\nTransaction Count: 1\nTotal Transaction Amount: 344.98
# 1902  From: 9997\nTo: 9863\nTransaction Count: 1\nTotal Transaction Amount: 260.85
#
#                                                                              click
# 0        From: 28\nTo: 9984\nTransaction Count: 1\nTotal Transaction Amount: 95.65
# 1        From: 48\nTo: 9256\nTransaction Count: 1\nTotal Transaction Amount: 61.93
# 2         From: 53\nTo: 9600\nTransaction Count: 1\nTotal Transaction Amount: 44.0
# 3        From: 60\nTo: 9328\nTransaction Count: 1\nTotal Transaction Amount: 60.48
# 4        From: 70\nTo: 4385\nTransaction Count: 2\nTotal Transaction Amount: 79.28
# ...                                                                            ...
# 1898  From: 9990\nTo: 3759\nTransaction Count: 1\nTotal Transaction Amount: 209.22
# 1899  From: 9995\nTo: 1217\nTransaction Count: 1\nTotal Transaction Amount: 394.35
# 1900  From: 9996\nTo: 2428\nTransaction Count: 1\nTotal Transaction Amount: 344.98
# 1901  From: 9996\nTo: 9993\nTransaction Count: 1\nTotal Transaction Amount: 344.98
# 1902  From: 9997\nTo: 9863\nTransaction Count: 1\nTotal Transaction Amount: 260.85
#
# [1903 rows x 6 columns]

# %% [markdown]
# <h4>Creating our network using NetworkX</h4>

# %%
aml_net = nx.from_pandas_edgelist(aml_df,source="SENDER_ACCOUNT_ID",target="RECEIVER_ACCOUNT_ID",edge_attr=["TOTAL_TXN_AMOUNT","hover","click"], create_using = nx.DiGraph())

# %% [markdown]
# <h4>
#     Creating a group dict to add a group attribute to our nodes. Which will make it easier to identify nodes belonging to the same community or from AML POV belonging to the same criminal syndicate.
# </h4>

# %%
group_dict = dict()
for group, nodes in enumerate(nx.weakly_connected_components(aml_net)):
    for i in nodes:
        group_dict[i] = group

pd.DataFrame({"node": group_dict.keys(), "group": group_dict.values()}).groupby(["group"]).agg({"node":"count"}).sort_values(by=["node"],ascending=False)
# Out:
#        node
# group
# 25       33
# 50       23
# 158      21
# 237      20
# 105      19
# ...     ...
# 432       2
# 435       2
# 436       2
# 1020      2
# 429       1
#
# [1021 rows x 1 columns]

# %% [markdown]
# <h4>
#     Generating visually distinct colors for each group thus making it easier to differentiate nodes belonging to different groups by their color
# </h4>

# %%
color_dict = dict()

color_map = list(map(distinctipy.get_rgb256,distinctipy.get_colors(len(list(nx.weakly_connected_components(aml_net))))))

for node, group in group_dict.items():
    rgb_int = color_map[group]
    color_dict[node] = f"rgb({rgb_int[0]},{rgb_int[1]},{rgb_int[2]})"

# %% [markdown]
# <h4>
#     Setting the Node Attribute "color" using the previously generated color_dict
# </h4>

# %%
nx.set_node_attributes(aml_net,color_dict,"color")

# %% [markdown]
# <h4>
#     Setting the "size" attribute of the nodes as per their Degree. Degree refers to the no of different accounts that a person had transactions with.
# </h4>

# %%
degree_dict = dict(aml_net.degree)

nx.set_node_attributes(aml_net,degree_dict,"size")

# %% [markdown]
# <h4>
#     Generating and Setting the "hover" and "click" attributes of the nodes. Which contains their id, group, degree and neighbors
# </h4>

# %%
title_dict = dict()

for i in aml_net.nodes:
    title_dict[i] = f"id: {i}\ngroup: {group_dict[i]}\ndegree: {degree_dict[i]}\nneighbors: {", ".join(map(str,nx.all_neighbors(aml_net,i)))}"
nx.set_node_attributes(aml_net,title_dict,"hover")
nx.set_node_attributes(aml_net,title_dict,"click")

# %% [markdown]
# <h4>
#     Creating a helper function show_network to visualise network using gravis
# </h4>

# %%
def show_network(g_net):
    fig = gv.d3(g_net,graph_height=1000,use_node_size_normalization=True,edge_size_data_source="TOTAL_TXN_AMOUNT",use_edge_size_normalization=True,many_body_force_strength=-300,node_size_normalization_min=15,edge_size_normalization_min=1,node_hover_neighborhood=True,edge_curvature=.4)
    fig.display(inline=True)

# %% [markdown]
# <h3>
#     Visualizing the Network.
# </h3>
# <h4>
#     Gravis has beautifully displayed the network. But since this is a lot of information on one screen. It is difficult to analyse. Will focus on specific subgraphs in next stages.
# </h4>

# %%
show_network(aml_net)
# Out:
#   <style>
#     /* Main divisions */
#     #iEU5dGYfPkPzLl8f2-main-div {
#       line-height: normal;
#       box-sizing: content-box;
#       padding: 3px;
#       background-color: white;
#     }
#     #iEU5dGYfPkPzLl8f2-left-div {
#       float: left;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iEU5dGYfPkPzLl8f2-right-div {
#       float: left;
#       height: 100%;
#       display: none;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iEU5dGYfPkPzLl8f2-right-inner-div {
#       padding-left: 5px;
#       padding-right: 2px;
#       overflow-x: hidden;
#       overflow-y: auto;
#       height: 100%;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#
#     /* Graph and details (contained in left-inner-div) */
#     #iEU5dGYfPkPzLl8f2-graph-div {
#       overflow: hidden;
#       resize: vertical;
#       position: relative;
#       border: 1px solid #ccc;
#       border-radius: 4px;
#       box-shadow: 0px 0px 2px rgba(0, 0, 0, 0.2);
#       display: none;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iEU5dGYfPkPzLl8f2-details-div {
#       overflow: auto;
#       resize: vertical;
#       margin-top: 5px;
#       border: 1px solid #ccc;
#       border-radius: 4px;
#       box-shadow: 0px 0px 2px rgba(0, 0, 0, 0.2);
#       display: none;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iEU5dGYfPkPzLl8f2-details-head {
#       user-select: none;
#       padding-left: 4px !important;
#       padding-top: 4px !important;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: gray;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iEU5dGYfPkPzLl8f2-details-body {
#       padding: 10px;
#       padding-top: 6px;
#       font-size: 10px;
#       font-family: "Lucida Console", Monaco, monospace;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#
#     /* Control menu (contained in right-inner-div) */
#     .iEU5dGYfPkPzLl8f2-menu-item-head {
#       font-size: 11px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       cursor: pointer;
#       padding-left: 5px;
#       padding-right: 0px;
#       padding-top: 5px;
#       padding-bottom: 5px;
#       margin-bottom: 5px;
#       border-radius: 4px;
#       border: 1px solid #ccc;
#       box-shadow: 0px 0px 3px rgba(0, 0, 0, 0.2);
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .iEU5dGYfPkPzLl8f2-menu-item-body {
#       margin-left: 5px;
#       margin-bottom: 10px;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .iEU5dGYfPkPzLl8f2-menu-subitem-head {
#       font-size: 9px;
#       font-family: "Lucida Console", Monaco, monospace;
#       font-weight: 600;
#       color: #006429;
#       cursor: default;
#       margin-bottom: 2px;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .iEU5dGYfPkPzLl8f2-menu-subitem-body {
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       margin-left: 7px;
#       margin-bottom: 5px;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .iEU5dGYfPkPzLl8f2-labeled-input {
#       all: initial;
#       display: flex;
#       align-items: center;
#       margin-top: 1px;
#       margin-bottom: 1px;
#     }
#     .iEU5dGYfPkPzLl8f2-label {
#       all: initial;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       font-style: italic;
#       cursor: pointer;
#     }
#     .iEU5dGYfPkPzLl8f2-slider {
#       width: 100%;
#       margin-bottom: 2px;
#     }
#     .iEU5dGYfPkPzLl8f2-slider::-moz-focus-outer {
#       border: 0;
#     }
#     .iEU5dGYfPkPzLl8f2-slider-text-left {
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       font-style: italic;
#       color: black;
#       float: left;
#       margin-top: 2px;
#     }
#     .iEU5dGYfPkPzLl8f2-slider-text-right {
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       float: right;
#     }
#     .iEU5dGYfPkPzLl8f2-checkbox {
#       margin-left: 0px !important;
#       margin-right: 4px !important;
#       margin-top: 2px !important;
#       margin-bottom: 2px !important;
#       padding: 0px !important;
#     }
#     .iEU5dGYfPkPzLl8f2-select {
#       cursor: pointer;
#       outline: none;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       background-color: #f5f5f5;
#       width: 100%;
#       padding-top: 4px !important;
#       padding-bottom: 4px !important;
#       padding-left: 5px;
#       padding-right: 10px;
#       margin-right: 5px;
#       margin-top: 2px;
#       margin-bottom: 2px;
#       border-radius: 4px;
#       border: 1.2px solid #bbb;
#       box-shadow: 0 1px 0 1px rgba(0, 0, 0, 0.04);
#
#       -moz-appearance: none;
#       -webkit-appearance: none;
#       appearance: none;
#       background-image: url('...');
#       background-repeat: no-repeat;
#       background-position: right 4px top 50%;
#       background-size: 6px;
#     }
#     @-moz-document url-prefix() {
#       /* Dirty hack to remove dotted border on focus */
#       .iEU5dGYfPkPzLl8f2-select {
#         color: transparent !important;
#         text-shadow: 0 0 0 black !important;
#       }
#     }
#     .iEU5dGYfPkPzLl8f2-select:after {
#       cursor: pointer;
#     }
#     .iEU5dGYfPkPzLl8f2-button {
#       cursor: pointer;
#       outline: none;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       background-color: #f2f2f2;
#       padding-top: 4px !important;
#       padding-bottom: 4px !important;
#       padding-left: 10px;
#       padding-right: 10px;
#       margin-top: 2px;
#       margin-bottom: 2px;
#       border-radius: 4px;
#       border: 1.2px solid #bbb;
#       box-shadow: 0 1px 0 1px rgba(0, 0, 0, 0.04);
#     }
#     .iEU5dGYfPkPzLl8f2-button:hover {
#       border: 1.2px solid #999;
#       background-color: #f2f2f2;
#     }
#     .iEU5dGYfPkPzLl8f2-button:active {
#       background-color: #ddd;
#     }
#     .iEU5dGYfPkPzLl8f2-button::-moz-focus-inner {
#       border: 0;
#     }
#     /* Hidden menu items */
#     #iEU5dGYfPkPzLl8f2-graph-select-div {
#       display: none;
#     }
#     #iEU5dGYfPkPzLl8f2-node-size-norm-div {
#       display: none;
#     }
#     #iEU5dGYfPkPzLl8f2-edge-size-norm-div {
#       display: none;
#     }
#
#     /* Graph */
#     #iEU5dGYfPkPzLl8f2-tooltip-div {
#       font-size: 10px;
#       font-family: "Lucida Console", Monaco, monospace;
#       z-index: 42001;
#       opacity: 0;
#       visibility: hidden;
#       position: absolute !important;
#       max-width: 40%;
#       padding: 5px;
#       white-space: pre-wrap;
#       word-break: break-word;
#       color: black;
#       background-color: white;
#       border-radius: 4px;
#       border: 1px solid #ccc;
#       box-shadow: 0px 0px 4px rgba(0, 0, 0, 0.2);
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iEU5dGYfPkPzLl8f2-menu-toggle-button, #iEU5dGYfPkPzLl8f2-details-toggle-button, #iEU5dGYfPkPzLl8f2-progress-container {
#       font-size: 14px;
#       font-family: "Lucida Console", Monaco, monospace;
#       z-index: 42000;
#       cursor: pointer;
#       position: absolute;
#       background-color: white;
#       border-radius: 4px;
#       box-shadow: 0px 0px 4px rgba(0, 0, 0, 0.2);
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iEU5dGYfPkPzLl8f2-menu-toggle-button {
#       top: 0;
#       right: 0;
#       padding-left: 6px;
#       padding-right: 6px;
#       padding-top: 12px;
#       padding-bottom: 12px;
#       border-top: 0px;
#       border-right: 0px;
#       border-bottom: 1px solid #ccc;
#       border-left: 1px solid #ccc;
#     }
#     #iEU5dGYfPkPzLl8f2-details-toggle-button {
#       bottom: 0;
#       left: 0;
#       padding-left: 19px;
#       padding-right: 19px;
#       padding-top: 0.5px;
#       padding-bottom: 2px;
#       border-top: 1px solid #ccc;
#       border-right: 1px solid #ccc;
#       border-bottom: 0px;
#       border-left: 0px;
#     }
#     #iEU5dGYfPkPzLl8f2-progress-container {
#       font-size: 10px;
#       text-align: center;
#       top: 46%;
#       left: 15%;
#       width: 70%;
#       padding: 8px;
#       border: none

# %% [markdown]
# <h4>
#     Creating a subgraph for a few target syndicates and visualizing that
# </h4>

# %%
target_groups = [25,50,158,237,37]
target_group_nodes = list()
for node, group in group_dict.items():
    if group in target_groups:
        target_group_nodes.append(node)
target_groups_network = aml_net.subgraph(target_group_nodes)
show_network(target_groups_network)
# Out:
#   <style>
#     /* Main divisions */
#     #iRoTCrgZkhWNNUK27-main-div {
#       line-height: normal;
#       box-sizing: content-box;
#       padding: 3px;
#       background-color: white;
#     }
#     #iRoTCrgZkhWNNUK27-left-div {
#       float: left;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iRoTCrgZkhWNNUK27-right-div {
#       float: left;
#       height: 100%;
#       display: none;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iRoTCrgZkhWNNUK27-right-inner-div {
#       padding-left: 5px;
#       padding-right: 2px;
#       overflow-x: hidden;
#       overflow-y: auto;
#       height: 100%;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#
#     /* Graph and details (contained in left-inner-div) */
#     #iRoTCrgZkhWNNUK27-graph-div {
#       overflow: hidden;
#       resize: vertical;
#       position: relative;
#       border: 1px solid #ccc;
#       border-radius: 4px;
#       box-shadow: 0px 0px 2px rgba(0, 0, 0, 0.2);
#       display: none;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iRoTCrgZkhWNNUK27-details-div {
#       overflow: auto;
#       resize: vertical;
#       margin-top: 5px;
#       border: 1px solid #ccc;
#       border-radius: 4px;
#       box-shadow: 0px 0px 2px rgba(0, 0, 0, 0.2);
#       display: none;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iRoTCrgZkhWNNUK27-details-head {
#       user-select: none;
#       padding-left: 4px !important;
#       padding-top: 4px !important;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: gray;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iRoTCrgZkhWNNUK27-details-body {
#       padding: 10px;
#       padding-top: 6px;
#       font-size: 10px;
#       font-family: "Lucida Console", Monaco, monospace;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#
#     /* Control menu (contained in right-inner-div) */
#     .iRoTCrgZkhWNNUK27-menu-item-head {
#       font-size: 11px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       cursor: pointer;
#       padding-left: 5px;
#       padding-right: 0px;
#       padding-top: 5px;
#       padding-bottom: 5px;
#       margin-bottom: 5px;
#       border-radius: 4px;
#       border: 1px solid #ccc;
#       box-shadow: 0px 0px 3px rgba(0, 0, 0, 0.2);
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .iRoTCrgZkhWNNUK27-menu-item-body {
#       margin-left: 5px;
#       margin-bottom: 10px;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .iRoTCrgZkhWNNUK27-menu-subitem-head {
#       font-size: 9px;
#       font-family: "Lucida Console", Monaco, monospace;
#       font-weight: 600;
#       color: #006429;
#       cursor: default;
#       margin-bottom: 2px;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .iRoTCrgZkhWNNUK27-menu-subitem-body {
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       margin-left: 7px;
#       margin-bottom: 5px;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .iRoTCrgZkhWNNUK27-labeled-input {
#       all: initial;
#       display: flex;
#       align-items: center;
#       margin-top: 1px;
#       margin-bottom: 1px;
#     }
#     .iRoTCrgZkhWNNUK27-label {
#       all: initial;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       font-style: italic;
#       cursor: pointer;
#     }
#     .iRoTCrgZkhWNNUK27-slider {
#       width: 100%;
#       margin-bottom: 2px;
#     }
#     .iRoTCrgZkhWNNUK27-slider::-moz-focus-outer {
#       border: 0;
#     }
#     .iRoTCrgZkhWNNUK27-slider-text-left {
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       font-style: italic;
#       color: black;
#       float: left;
#       margin-top: 2px;
#     }
#     .iRoTCrgZkhWNNUK27-slider-text-right {
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       float: right;
#     }
#     .iRoTCrgZkhWNNUK27-checkbox {
#       margin-left: 0px !important;
#       margin-right: 4px !important;
#       margin-top: 2px !important;
#       margin-bottom: 2px !important;
#       padding: 0px !important;
#     }
#     .iRoTCrgZkhWNNUK27-select {
#       cursor: pointer;
#       outline: none;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       background-color: #f5f5f5;
#       width: 100%;
#       padding-top: 4px !important;
#       padding-bottom: 4px !important;
#       padding-left: 5px;
#       padding-right: 10px;
#       margin-right: 5px;
#       margin-top: 2px;
#       margin-bottom: 2px;
#       border-radius: 4px;
#       border: 1.2px solid #bbb;
#       box-shadow: 0 1px 0 1px rgba(0, 0, 0, 0.04);
#
#       -moz-appearance: none;
#       -webkit-appearance: none;
#       appearance: none;
#       background-image: url('...');
#       background-repeat: no-repeat;
#       background-position: right 4px top 50%;
#       background-size: 6px;
#     }
#     @-moz-document url-prefix() {
#       /* Dirty hack to remove dotted border on focus */
#       .iRoTCrgZkhWNNUK27-select {
#         color: transparent !important;
#         text-shadow: 0 0 0 black !important;
#       }
#     }
#     .iRoTCrgZkhWNNUK27-select:after {
#       cursor: pointer;
#     }
#     .iRoTCrgZkhWNNUK27-button {
#       cursor: pointer;
#       outline: none;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       background-color: #f2f2f2;
#       padding-top: 4px !important;
#       padding-bottom: 4px !important;
#       padding-left: 10px;
#       padding-right: 10px;
#       margin-top: 2px;
#       margin-bottom: 2px;
#       border-radius: 4px;
#       border: 1.2px solid #bbb;
#       box-shadow: 0 1px 0 1px rgba(0, 0, 0, 0.04);
#     }
#     .iRoTCrgZkhWNNUK27-button:hover {
#       border: 1.2px solid #999;
#       background-color: #f2f2f2;
#     }
#     .iRoTCrgZkhWNNUK27-button:active {
#       background-color: #ddd;
#     }
#     .iRoTCrgZkhWNNUK27-button::-moz-focus-inner {
#       border: 0;
#     }
#     /* Hidden menu items */
#     #iRoTCrgZkhWNNUK27-graph-select-div {
#       display: none;
#     }
#     #iRoTCrgZkhWNNUK27-node-size-norm-div {
#       display: none;
#     }
#     #iRoTCrgZkhWNNUK27-edge-size-norm-div {
#       display: none;
#     }
#
#     /* Graph */
#     #iRoTCrgZkhWNNUK27-tooltip-div {
#       font-size: 10px;
#       font-family: "Lucida Console", Monaco, monospace;
#       z-index: 42001;
#       opacity: 0;
#       visibility: hidden;
#       position: absolute !important;
#       max-width: 40%;
#       padding: 5px;
#       white-space: pre-wrap;
#       word-break: break-word;
#       color: black;
#       background-color: white;
#       border-radius: 4px;
#       border: 1px solid #ccc;
#       box-shadow: 0px 0px 4px rgba(0, 0, 0, 0.2);
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iRoTCrgZkhWNNUK27-menu-toggle-button, #iRoTCrgZkhWNNUK27-details-toggle-button, #iRoTCrgZkhWNNUK27-progress-container {
#       font-size: 14px;
#       font-family: "Lucida Console", Monaco, monospace;
#       z-index: 42000;
#       cursor: pointer;
#       position: absolute;
#       background-color: white;
#       border-radius: 4px;
#       box-shadow: 0px 0px 4px rgba(0, 0, 0, 0.2);
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iRoTCrgZkhWNNUK27-menu-toggle-button {
#       top: 0;
#       right: 0;
#       padding-left: 6px;
#       padding-right: 6px;
#       padding-top: 12px;
#       padding-bottom: 12px;
#       border-top: 0px;
#       border-right: 0px;
#       border-bottom: 1px solid #ccc;
#       border-left: 1px solid #ccc;
#     }
#     #iRoTCrgZkhWNNUK27-details-toggle-button {
#       bottom: 0;
#       left: 0;
#       padding-left: 19px;
#       padding-right: 19px;
#       padding-top: 0.5px;
#       padding-bottom: 2px;
#       border-top: 1px solid #ccc;
#       border-right: 1px solid #ccc;
#       border-bottom: 0px;
#       border-left: 0px;
#     }
#     #iRoTCrgZkhWNNUK27-progress-container {
#       font-size: 10px;
#       text-align: center;
#       top: 46%;
#       left: 15%;
#       width: 70%;
#       padding: 8px;
#       border: none

# %% [markdown]
# <h4>
#     Creating a subgraph starting with a few target account ids that we want to analyse on. I have also highlighted those nodes in the visualization by assigning it an differentiating image. In this way we can easily create the end to end fund flow network starting with any suspected account which otherwise would have taken a lot of manpower if done manually.
# </h4>

# %%
target_nodes = [4155,9922,8316,7803,9070]

target_group_nodes = list()

for node, group in group_dict.items():
    if group in [group_dict[i] for i in target_nodes]:
        target_group_nodes.append(node)

target_node_network = aml_net.subgraph(target_group_nodes).copy()

for node, data in target_node_network.nodes(data=True):
    if node in target_nodes:
        data["image"] = "https://openmoji.org/data/color/svg/1F4B0.svg"
        data["opacity"] = 0.2
        data["size"] = 3
        data["color"] = "red"

show_network(target_node_network)
# Out:
#   <style>
#     /* Main divisions */
#     #iMprk7nI3qPx7rSdh-main-div {
#       line-height: normal;
#       box-sizing: content-box;
#       padding: 3px;
#       background-color: white;
#     }
#     #iMprk7nI3qPx7rSdh-left-div {
#       float: left;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iMprk7nI3qPx7rSdh-right-div {
#       float: left;
#       height: 100%;
#       display: none;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iMprk7nI3qPx7rSdh-right-inner-div {
#       padding-left: 5px;
#       padding-right: 2px;
#       overflow-x: hidden;
#       overflow-y: auto;
#       height: 100%;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#
#     /* Graph and details (contained in left-inner-div) */
#     #iMprk7nI3qPx7rSdh-graph-div {
#       overflow: hidden;
#       resize: vertical;
#       position: relative;
#       border: 1px solid #ccc;
#       border-radius: 4px;
#       box-shadow: 0px 0px 2px rgba(0, 0, 0, 0.2);
#       display: none;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iMprk7nI3qPx7rSdh-details-div {
#       overflow: auto;
#       resize: vertical;
#       margin-top: 5px;
#       border: 1px solid #ccc;
#       border-radius: 4px;
#       box-shadow: 0px 0px 2px rgba(0, 0, 0, 0.2);
#       display: none;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iMprk7nI3qPx7rSdh-details-head {
#       user-select: none;
#       padding-left: 4px !important;
#       padding-top: 4px !important;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: gray;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iMprk7nI3qPx7rSdh-details-body {
#       padding: 10px;
#       padding-top: 6px;
#       font-size: 10px;
#       font-family: "Lucida Console", Monaco, monospace;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#
#     /* Control menu (contained in right-inner-div) */
#     .iMprk7nI3qPx7rSdh-menu-item-head {
#       font-size: 11px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       cursor: pointer;
#       padding-left: 5px;
#       padding-right: 0px;
#       padding-top: 5px;
#       padding-bottom: 5px;
#       margin-bottom: 5px;
#       border-radius: 4px;
#       border: 1px solid #ccc;
#       box-shadow: 0px 0px 3px rgba(0, 0, 0, 0.2);
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .iMprk7nI3qPx7rSdh-menu-item-body {
#       margin-left: 5px;
#       margin-bottom: 10px;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .iMprk7nI3qPx7rSdh-menu-subitem-head {
#       font-size: 9px;
#       font-family: "Lucida Console", Monaco, monospace;
#       font-weight: 600;
#       color: #006429;
#       cursor: default;
#       margin-bottom: 2px;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .iMprk7nI3qPx7rSdh-menu-subitem-body {
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       margin-left: 7px;
#       margin-bottom: 5px;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .iMprk7nI3qPx7rSdh-labeled-input {
#       all: initial;
#       display: flex;
#       align-items: center;
#       margin-top: 1px;
#       margin-bottom: 1px;
#     }
#     .iMprk7nI3qPx7rSdh-label {
#       all: initial;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       font-style: italic;
#       cursor: pointer;
#     }
#     .iMprk7nI3qPx7rSdh-slider {
#       width: 100%;
#       margin-bottom: 2px;
#     }
#     .iMprk7nI3qPx7rSdh-slider::-moz-focus-outer {
#       border: 0;
#     }
#     .iMprk7nI3qPx7rSdh-slider-text-left {
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       font-style: italic;
#       color: black;
#       float: left;
#       margin-top: 2px;
#     }
#     .iMprk7nI3qPx7rSdh-slider-text-right {
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       float: right;
#     }
#     .iMprk7nI3qPx7rSdh-checkbox {
#       margin-left: 0px !important;
#       margin-right: 4px !important;
#       margin-top: 2px !important;
#       margin-bottom: 2px !important;
#       padding: 0px !important;
#     }
#     .iMprk7nI3qPx7rSdh-select {
#       cursor: pointer;
#       outline: none;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       background-color: #f5f5f5;
#       width: 100%;
#       padding-top: 4px !important;
#       padding-bottom: 4px !important;
#       padding-left: 5px;
#       padding-right: 10px;
#       margin-right: 5px;
#       margin-top: 2px;
#       margin-bottom: 2px;
#       border-radius: 4px;
#       border: 1.2px solid #bbb;
#       box-shadow: 0 1px 0 1px rgba(0, 0, 0, 0.04);
#
#       -moz-appearance: none;
#       -webkit-appearance: none;
#       appearance: none;
#       background-image: url('...');
#       background-repeat: no-repeat;
#       background-position: right 4px top 50%;
#       background-size: 6px;
#     }
#     @-moz-document url-prefix() {
#       /* Dirty hack to remove dotted border on focus */
#       .iMprk7nI3qPx7rSdh-select {
#         color: transparent !important;
#         text-shadow: 0 0 0 black !important;
#       }
#     }
#     .iMprk7nI3qPx7rSdh-select:after {
#       cursor: pointer;
#     }
#     .iMprk7nI3qPx7rSdh-button {
#       cursor: pointer;
#       outline: none;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       background-color: #f2f2f2;
#       padding-top: 4px !important;
#       padding-bottom: 4px !important;
#       padding-left: 10px;
#       padding-right: 10px;
#       margin-top: 2px;
#       margin-bottom: 2px;
#       border-radius: 4px;
#       border: 1.2px solid #bbb;
#       box-shadow: 0 1px 0 1px rgba(0, 0, 0, 0.04);
#     }
#     .iMprk7nI3qPx7rSdh-button:hover {
#       border: 1.2px solid #999;
#       background-color: #f2f2f2;
#     }
#     .iMprk7nI3qPx7rSdh-button:active {
#       background-color: #ddd;
#     }
#     .iMprk7nI3qPx7rSdh-button::-moz-focus-inner {
#       border: 0;
#     }
#     /* Hidden menu items */
#     #iMprk7nI3qPx7rSdh-graph-select-div {
#       display: none;
#     }
#     #iMprk7nI3qPx7rSdh-node-size-norm-div {
#       display: none;
#     }
#     #iMprk7nI3qPx7rSdh-edge-size-norm-div {
#       display: none;
#     }
#
#     /* Graph */
#     #iMprk7nI3qPx7rSdh-tooltip-div {
#       font-size: 10px;
#       font-family: "Lucida Console", Monaco, monospace;
#       z-index: 42001;
#       opacity: 0;
#       visibility: hidden;
#       position: absolute !important;
#       max-width: 40%;
#       padding: 5px;
#       white-space: pre-wrap;
#       word-break: break-word;
#       color: black;
#       background-color: white;
#       border-radius: 4px;
#       border: 1px solid #ccc;
#       box-shadow: 0px 0px 4px rgba(0, 0, 0, 0.2);
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iMprk7nI3qPx7rSdh-menu-toggle-button, #iMprk7nI3qPx7rSdh-details-toggle-button, #iMprk7nI3qPx7rSdh-progress-container {
#       font-size: 14px;
#       font-family: "Lucida Console", Monaco, monospace;
#       z-index: 42000;
#       cursor: pointer;
#       position: absolute;
#       background-color: white;
#       border-radius: 4px;
#       box-shadow: 0px 0px 4px rgba(0, 0, 0, 0.2);
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iMprk7nI3qPx7rSdh-menu-toggle-button {
#       top: 0;
#       right: 0;
#       padding-left: 6px;
#       padding-right: 6px;
#       padding-top: 12px;
#       padding-bottom: 12px;
#       border-top: 0px;
#       border-right: 0px;
#       border-bottom: 1px solid #ccc;
#       border-left: 1px solid #ccc;
#     }
#     #iMprk7nI3qPx7rSdh-details-toggle-button {
#       bottom: 0;
#       left: 0;
#       padding-left: 19px;
#       padding-right: 19px;
#       padding-top: 0.5px;
#       padding-bottom: 2px;
#       border-top: 1px solid #ccc;
#       border-right: 1px solid #ccc;
#       border-bottom: 0px;
#       border-left: 0px;
#     }
#     #iMprk7nI3qPx7rSdh-progress-container {
#       font-size: 10px;
#       text-align: center;
#       top: 46%;
#       left: 15%;
#       width: 70%;
#       padding: 8px;
#       border: none

# %% [markdown]
# <h3>
#     This is the most powerful use case in AML investigation which allow you to identify all related accounts from an end-to-end perspective, staring with any given node
# </h3>
